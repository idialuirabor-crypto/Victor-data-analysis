# %% [markdown]
# # is for Heading
# # Python Class
# ## Python Class
# # Python Class

# %% [markdown]
# *Class* - Single is to Italizise
#
# **Class** is to Bold

# %%
(-) is for bullet point
- Python
- Excel
- PowerBI
  - SQL
     - PowerQuery

# %% [raw]
# RAW leaves things as it is.
# # Python

# %%
g = 2345*4567
g
# Out:
# 10709615

# %%
g
# Out:
# 10709615

# %% [markdown]
# # Python data Structure
# # List

# %%
w = ["Ada", 25, "Bianca", 18, "Victor", 28, "Godwin", 23]

# %%
w
# Out:
# ['Ada', 25, 'Bianca', 18, 'Victor', 28, 'Godwin', 23]

# %%
type(w)
# Out:
# list

# %%
w.append("Aisha")

# %%
w.append(25)

# %%
w
# Out:
# ['Ada', 25, 'Bianca', 18, 'Victor', 28, 'Godwin', 23, 'Aisha', 25]

# %%
w.extend(["James", 24])

# %%
w
# Out:
# ['Ada', 25, 'Bianca', 18, 'Victor', 28, 'Godwin', 23, 'Aisha', 25, 'James', 24]

# %%
w.insert(3, "Bianca")

# %%
w.remove("Bianca")

# %%
w.pop(-1)
# Out:
# 'James'

# %%
w.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 w.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
len(w)
# Out:
# 10

# %%
w
# Out:
# ['Ada', 25, 'Bianca', 18, 'Victor', 28, 'Godwin', 23, 'Aisha', 25]

# %%
w.reverse()

# %%
w
# Out:
# [25, 'Aisha', 23, 'Godwin', 28, 'Victor', 18, 'Bianca', 25, 'Ada']

# %%
w.count(25)
# Out:
# 2

# %% [markdown]
# # Tuple

# %% [raw]
# - Ordered
# - Immutable
# - Allows Duplicatate

# %%
t = ("Favour", 33, "Afe", 23)

# %%
t.

# %% [markdown]
# # Set

# %% [raw]
# - UNORDERED
# - MUTABLE
# - NO DUPLICATES

# %%
s = {"Ada", 23, "Viv", 23, "Godwin", 24, "Mercy", 25}

# %%
s
# Out:
# {23, 24, 25, 'Ada', 'Godwin', 'Mercy', 'Viv'}

# %%
s.add("TommyG")

# %%
type(s)
# Out:
# set

# %% [markdown]
# # Dictionary:

# %% [raw]
# * if you want to create a table also known as data frame, we use dictionary.
# - Ordered
# - Mutable
# -Keys Must be unique

# %%
d = {"Name": ["Afe", "Victor", "Sam", "Ada", "Bianca", "Faith", "Vivian", "Aisha"],
 "Age": [23, 26, 32, 25, 27, 25, 24,27],
 "Gender": ["Male", "Male", "Male", "Female", "Female", "Female", "Female", "Female"],
"Fav_course": [None, "Excel", None, "PowerBI", "SQL", "Python", None, "Tablue"]}

# %%
import pandas as pd

# %%
table = pd.DataFrame(d)

# %%
table
# Out:
#      Name  Age  Gender Fav_course
# 0     Afe   23    Male       None
# 1  Victor   26    Male      Excel
# 2     Sam   32    Male       None
# 3     Ada   25  Female    PowerBI
# 4  Bianca   27  Female        SQL
# 5   Faith   25  Female     Python
# 6  Vivian   24  Female       None
# 7   Aisha   27  Female     Tablue

# %%
table.

# %%
print(d)
# Out:
# {'Name': ['Afe', 'Victor', 'Sam', 'Ada', 'Bianca', 'Faith', 'Vivian', 'Aisha'], 'Age': [23, 26, 32, 25, 27, 25, 24, 27], 'Gender': ['Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female'], 'Fav_course': [None, 'Excel', None, 'PowerBI', 'SQL', 'Python', None, 'Tablue']}

# %%
d["state"] = ["lagos", "Edo", "Abuja", "Kaduna", "jos", "Wuse", "Nasarawa", "Benue"]

# %%
d
# Out:
# {'Name': ['Afe', 'Victor', 'Sam', 'Ada', 'Bianca', 'Faith', 'Vivian', 'Aisha'],
#  'Age': [23, 26, 32, 25, 27, 25, 24, 27],
#  'Gender': ['Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Female'],
#  'Fav_course': [None,
#   'Excel',
#   None,
#   'PowerBI',
#   'SQL',
#   'Python',
#   None,
#   'Tablue'],
#  'state': ['lagos',
#   'Edo',
#   'Abuja',
#   'Kaduna',
#   'jos',
#   'Wuse',
#   'Nasarawa',
#   'Benue']}

# %%
print(d)
# Out:
# {'Name': ['Afe', 'Victor', 'Sam', 'Ada', 'Bianca', 'Faith', 'Vivian', 'Aisha'], 'Age': [23, 26, 32, 25, 27, 25, 24, 27], 'Gender': ['Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female'], 'Fav_course': [None, 'Excel', None, 'PowerBI', 'SQL', 'Python', None, 'Tablue'], 'state': ['lagos', 'Edo', 'Abuja', 'Kaduna']}

# %%
d.items()
# Out:
# dict_items([('Name', ['Afe', 'Victor', 'Sam', 'Ada', 'Bianca', 'Faith', 'Vivian', 'Aisha']), ('Age', [23, 26, 32, 25, 27, 25, 24, 27]), ('Gender', ['Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female']), ('Fav_course', [None, 'Excel', None, 'PowerBI', 'SQL', 'Python', None, 'Tablue']), ('state', ['lagos', 'Edo', 'Abuja', 'Kaduna'])])

# %%
import pandas as pd

# %%
pd.DataFrame(d)
# Out:
#      Name  Age  Gender Fav_course     state
# 0     Afe   23    Male       None     lagos
# 1  Victor   26    Male      Excel       Edo
# 2     Sam   32    Male       None     Abuja
# 3     Ada   25  Female    PowerBI    Kaduna
# 4  Bianca   27  Female        SQL       jos
# 5   Faith   25  Female     Python      Wuse
# 6  Vivian   24  Female       None  Nasarawa
# 7   Aisha   27  Female     Tablue     Benue

# %%
import pan
